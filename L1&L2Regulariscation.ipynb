# %%
#import libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#Suppress warnings for clean notebook
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv('C:\\Users\\ARPIT DUBEY\\Melbourne_housing_FULL.csv')
dataset.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03-09-2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  03-12-2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  04-02-2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  04-02-2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  04-03-2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
dataset.shape
# Out:
# (34857, 21)

# %%
#just making sure ki humare dataset mai sirf useful columns ho 
cols_to_use = ['Suburb', 'Rooms', 'Type', 'Method', 'SellerG', 'Regionname', 'Propertycount',
               'Distance', 'CouncilArea', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 
               'BuildingArea', 'Price']

dataset = dataset[cols_to_use]
dataset.head()
# Out:
#        Suburb  Rooms Type Method SellerG             Regionname  \
# 0  Abbotsford      2    h     SS  Jellis  Northern Metropolitan
# 1  Abbotsford      2    h      S  Biggin  Northern Metropolitan
# 2  Abbotsford      2    h      S  Biggin  Northern Metropolitan
# 3  Abbotsford      3    u     VB  Rounds  Northern Metropolitan
# 4  Abbotsford      3    h     SP  Biggin  Northern Metropolitan
#
#    Propertycount  Distance         CouncilArea  Bedroom2  Bathroom  Car  \
# 0         4019.0       2.5  Yarra City Council       2.0       1.0  1.0
# 1         4019.0       2.5  Yarra City Council       2.0       1.0  1.0
# 2         4019.0       2.5  Yarra City Council       2.0       1.0  0.0
# 3         4019.0       2.5  Yarra City Council       3.0       2.0  1.0
# 4         4019.0       2.5  Yarra City Council       3.0       2.0  0.0
#
#    Landsize  BuildingArea      Price
# 0     126.0           NaN        NaN
# 1     202.0           NaN  1480000.0
# ...

# %%
dataset.shape
# Out:
# (34857, 15)

# %%
#finding the sum of NaN values in the respective columns!
dataset.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Regionname           3
# Propertycount        0
# Distance             0
# CouncilArea          3
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize         11810
# BuildingArea     21115
# Price             7610
# dtype: int64

# %%
#filling the columns mentioned as 0 in there NaN position!
cols_to_fill_zero = ['Propertycount', 'Distance', 'Bedroom2', 'Bathroom', 'Car']
dataset[cols_to_fill_zero] = dataset[cols_to_fill_zero].fillna(0)
dataset.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Regionname           3
# Propertycount        0
# Distance             0
# CouncilArea          3
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize         11810
# BuildingArea     21115
# Price             7610
# dtype: int64

# %%
#for the remainig columns using mean() in fillna
dataset['Landsize'] = dataset['Landsize'].fillna(dataset.Landsize.mean())
dataset['BuildingArea'] = dataset['BuildingArea'].fillna(dataset.BuildingArea.mean())

dataset.isna().sum()
# Out:
# Suburb              0
# Rooms               0
# Type                0
# Method              0
# SellerG             0
# Regionname          3
# Propertycount       0
# Distance            0
# CouncilArea         3
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# Price            7610
# dtype: int64

# %%
#dropping the NaN values jinka itna kaam nhi h, is the one who will not affect the dataset

dataset.dropna(inplace=True)
dataset.isna().sum()
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Method           0
# SellerG          0
# Regionname       0
# Propertycount    0
# Distance         0
# CouncilArea      0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# Price            0
# dtype: int64

# %%
#now get_dummies for the categorical features 
dataset = pd.get_dummies(dataset,drop_first=True) #drop_first means jinpe dummies ban rhe hoi woh columns ko hta dena !!
dataset.head()
# Out:
#    Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 1      2         4019.0       2.5       2.0       1.0  1.0     202.0
# 2      2         4019.0       2.5       2.0       1.0  0.0     156.0
# 4      3         4019.0       2.5       3.0       2.0  0.0     134.0
# 5      3         4019.0       2.5       3.0       2.0  1.0      94.0
# 6      4         4019.0       2.5       3.0       1.0  2.0     120.0
#
#    BuildingArea      Price  Suburb_Aberfeldie  ...  \
# 1      160.2564  1480000.0              False  ...
# 2       79.0000  1035000.0              False  ...
# 4      150.0000  1465000.0              False  ...
# 5      160.2564   850000.0              False  ...
# 6      142.0000  1600000.0              False  ...
#
#    CouncilArea_Moorabool Shire Council  CouncilArea_Moreland City Council  \
# 1                                False                              False
# 2                                False                              False
# ...

# %%
X = dataset.drop('Price',axis='columns')
y= dataset['Price']

# %%
from sklearn.model_selection import train_test_split
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.3, random_state=2)

# %%
from sklearn.linear_model import LinearRegression
le = LinearRegression()

# %%
reg = le.fit(train_X,train_y)

# %%
#score while testing!

reg.score(test_X,test_y)
# Out:
# 0.13853683161380637

# %%
#score while training

reg.score(train_X,train_y)
# Out:
# 0.6827792395792723

# %%
# as you can clearly see , the training the testing score is having a huge difference !!
# this is how overfit looks like !

# %%
# IN order to solve this we use L1 and L2 regularisation !!

# %%
#L1 Regularisation Using Lasso !!

from sklearn import linear_model

lasso_reg = linear_model.Lasso(alpha=50,max_iter=100,tol =0.1)

lasso_reg.fit(train_X,train_y)
# Out:
# Lasso(alpha=50, max_iter=100, tol=0.1)

# %%
lasso_reg.score(train_X,train_y)
# Out:
# 0.6766985624766824

# %%
# Now you can see , test score has inc from 0.14 to 0.66
lasso_reg.score(test_X,test_y)
# Out:
# 0.6636111369404489

# %%
#L2 regularisation Using Ridge!

from sklearn.linear_model import Ridge

ridge_reg = Ridge(alpha=50,max_iter=100,tol=0.1)
ridge_reg.fit(train_X,train_y)
# Out:
# Ridge(alpha=50, max_iter=100, tol=0.1)

# %%
ridge_reg.score(train_X,train_y)
# Out:
# 0.6622376739684328

# %%
# through L2 using ridge , the score inc!!
ridge_reg.score(test_X,test_y)
# Out:
# 0.6670848945194958
